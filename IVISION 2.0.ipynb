# %%
import cv2
import os
from tqdm import tqdm
import numpy as np
from shutil import copyfile

# %%
def image2folders(path, savepath, razmetka, step=1):
    for folder in razmetka:
        os.makedirs(os.path.join(savepath, str(folder)), exist_ok=True)
        if len(razmetka[folder])>1:
            for ind in range(0,len(razmetka[folder]),2):
                ind = int(ind)
                start = razmetka[folder][ind]
                end = razmetka[folder][ind+1]
                print(start, end)
                for filename in range(start,end+1, step):
                    filename = str(int(filename))
                    filename+=".jpg"
                    copyfile(os.path.join(path, str(folder), filename), os.path.join(savepath, str(folder), filename))
        else:
            start = razmetka[folder][0]
            end = len(os.listdir(os.path.join(path, str(folder))))
            for filename in range(start,end, step):
                    filename = str(int(filename))
                    filename+=".jpg"
                    copyfile(os.path.join(path, str(folder), filename), os.path.join(savepath, str(folder), filename))

# %%
def video2images(filepath, savepath, when=3):
    os.makedirs(savepath, exist_ok=True)
    cap = cv2.VideoCapture(filepath)
    images = []
    count = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        if count%when==0:
            images.append(frame)
        count+=1
    for i,image in enumerate(images):
        cv2.imwrite(os.path.join(savepath, str(i)+".jpg"), image)

# %%
dtp_path = r"E:\IVISION\dtp"
dtp_savepath = r"E:\IVISION\dtp_images"

# %%
for file in tqdm(os.listdir(dtp_path)):
    video2images(os.path.join(dtp_path, file), os.path.join(dtp_savepath, file.split(".")[0]))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [05:37<00:00, 13.52s/it]

# %%
no_dtp = r"E:\IVISION\no"
no_dtp_savepath = r"E:\IVISION\no_images"

# %%
for file in tqdm(os.listdir(no_dtp)):
    video2images(os.path.join(no_dtp, file), os.path.join(no_dtp_savepath, file.split(".")[0]))
# Out:
#   4%|███                                                                                | 1/27 [00:19<08:34, 19.77s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\331A~1\AppData\Local\Temp/ipykernel_11424/2407394216.py in <module>
#       1 for file in tqdm(os.listdir(no_dtp)):
# ----> 2     video2images(os.path.join(no_dtp, file), os.path.join(r"E:\IVISION\test", file.split(".")[0]))
#
# C:\Users\331A~1\AppData\Local\Temp/ipykernel_11424/3563775361.py in video2images(filepath, savepath, when)
#      12         count+=1
#      13     for i,image in enumerate(images):
# ---> 14         cv2.imwrite(os.path.join(savepath, str(i)+".jpg"), image)
#      15
#
# KeyboardInterrupt:

# %%
razmetka = {}

# %%
razmetka[1] = [125,140]
razmetka[2] = [189,201,225,227,260,267,315,319]
#razmetka[4] = [33]
razmetka[5] = [131,140,247,256,300,303]
razmetka[7] = [190,199,250,255]
razmetka[8] = [151,154,171,177,217,222]
razmetka[9] = [114]
razmetka[10] = [249,261,325,330,364,370]
razmetka[11] = [180,185,213,220]
razmetka[12] = [155,244,387,398]
razmetka[13] = [170,185]
razmetka[14] = [223,236,273,280]
razmetka[15] = [141,151,171,173,185,188,194,196]
razmetka[20] = [44,121]
razmetka[21] = [83,131,174,180]
razmetka[22] = [0,55]
razmetka[24] = [155,180,187,192,303,305,347,350,361,370]
razmetka[27] = [152,181,250,256]
razmetka[32] = [72,126]
razmetka[33] = [124,128,161,165]
razmetka[36] = [196, 210]
#razmetka[39] = []
razmetka[50] = [1105,1142]

# %%
razmetka[1] = [125,140]
razmetka[2] = [189,201,225,227,260,267,315,319]
#razmetka[4] = [33]
razmetka[5] = [131,140,247,256,300,303]
razmetka[7] = [190,199,250,255]
razmetka[8] = [151,154,171,177,217,222]
razmetka[9] = [114]
razmetka[10] = [249,261,325,330,364,370]
razmetka[11] = [180,185,213,220]
razmetka[12] = [155,244,387,398]
razmetka[13] = [170,185]
razmetka[14] = [223,236,273,280]
razmetka[15] = [141,151,171,173,185,188,194,196]
razmetka[20] = [44,121]
razmetka[21] = [83,131,174,180]
razmetka[22] = [0,55]
razmetka[24] = [155,180,187,192,303,305,347,350,361,370]
razmetka[27] = [152,181,250,256]
razmetka[32] = [72,126]
razmetka[33] = [124,128,161,165]
razmetka[36] = [196, 210]
#razmetka[39] = []
razmetka[50] = [1105,1142]

# %%
dtp_time = {}

# %%
dtp_time[1] = [81,115]
dtp_time[2] = [189,201,225,227,260,267,315,319]
dtp_time[4] = [31,76]
dtp_time[5] = [30,60,136,150]
dtp_time[7] = [74,105,179,185,190,200]
dtp_time[8] = [64,110,161,180]
dtp_time[9] = [67,95,121,155]
dtp_time[10] = [70,125,230,240,263,274]
dtp_time[11] = [49,87,141,145,210,215]
dtp_time[12] = [25,84,162,195]
dtp_time[13] = [68,87,179,220]
dtp_time[14] = [52,86,154,164,230,254]
dtp_time[15] = [65,120,160,170]
dtp_time[20] = [44,90]
dtp_time[21] = [17,42,95,129,170,184]
dtp_time[22] = [32,62,220,225]
dtp_time[24] = [51,70,161,180,363,370]
dtp_time[27] = [17,80,153,200]
dtp_time[32] = [77,110]
dtp_time[33] = [40,70,128,131,196,199]
dtp_time[36] = [70,100,195,207]
dtp_time[39] = [0,10]
dtp_time[50] = [10,20,200,215,500,520,960,1000,1110,1130]

# %%
image2folders(r"E:\IVISION\dtp_images",r"E:\IVISION\object_detection", razmetka)
# Out:
# 125 140
# 189 201
# 225 227
# 260 267
# 315 319
# 131 140
# 247 256
# 300 303
# 190 199
# 250 255
# 151 154
# 171 177
# 217 222
# 249 261
# 325 330
# 364 370
# 180 185
# 213 220
# 155 244
# 387 398
# 170 185
# 223 236
# 273 280
# 141 151
# 171 173
# 185 188
# 194 196
# 44 121
# 83 131
# 174 180
# 0 55
# 155 180
# 187 192
# 303 305
# 347 350
# 361 370
# 152 181
# 250 256
# 72 126
# 124 128
# 161 165
# 196 210
# 1105 1142

# %%
object_path = r"E:\IVISION\object_detection"
save_path = r"E:\IVISION\object_detection\all"
for folder in os.listdir(object_path):
    for file in os.listdir(os.path.join(object_path,folder)):
        copyfile(os.path.join(object_path,folder,file), os.path.join(save_path,folder+"_"+file))

# %%
train_images = os.listdir(r"E:\IVISION\IVISION detection.v3i.yolov5pytorch\test\images")

# %%
train_images_new = [x.split(".")[0] for x in train_images]

# %%
train_images_new = [x[0:len(x)-4]+".jpg" for x in train_images_new]

# %%
train_path = r"E:\IVISION\IVISION detection.v3i.yolov5pytorch\test\images"
images_path = r"E:\IVISION\object_detection\all"

# %%
for i,file in enumerate(train_images):
    os.remove(os.path.join(train_path,file))
    copyfile(os.path.join(images_path, train_images_new[i]), os.path.join(train_path,file))

# %%
dtp_path = r"E:\IVISION\dtp"
dtp_savepath = r"E:\IVISION\test_positive"
for file in tqdm(os.listdir(dtp_path)):
    video2images(os.path.join(dtp_path, file), os.path.join(dtp_savepath, file.split(".")[0]),when=30)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [01:59<00:00,  5.18s/it]

# %%
object_path = r"E:\IVISION\test_positive"
save_path = r"E:\IVISION\test_positive"
for folder in os.listdir(object_path):
    os.makedirs(save_path, exist_ok=True)
    for file in os.listdir(os.path.join(object_path,folder)):
        copyfile(os.path.join(object_path,folder,file), os.path.join(save_path,folder+"_"+file))

# %% [markdown]
# # TRAINING

# %%
import wandb
wandb.login()
# Out:
# wandb: Currently logged in as: victor30608 (use `wandb login --relogin` to force relogin)
# True

# %%
cd "S:\WORK\yolov5"
# Out:
# S:\WORK\yolov5

# %%
# !python train.py --img 1280 --batch -1 --epochs 25 --data "E:\IVISION\IVISION detection.v3i.yolov5pytorch\data.yaml" --weights yolov5l6.pt --project "ivision" --name "yolov5l6_1280_with_hard"
# Out:
# github:  YOLOv5 is out of date by 40 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
#
#       Params      GFLOPs  GPU_mem (GB)  forward (ms) backward (ms)                   input                  output
#     76162504       440.7         3.198          67.7         95.41      (1, 3, 1280, 1280)                    list
#     76162504       881.4         5.394         107.4         169.8      (2, 3, 1280, 1280)                    list
#     76162504        1763         9.137         220.6         437.3      (4, 3, 1280, 1280)                    list
# CUDA out of memory. Tried to allocate 26.00 MiB (GPU 0; 12.00 GiB total capacity; 10.11 GiB already allocated; 0 bytes free; 10.29 GiB reserved in total by PyTorch)
# CUDA out of memory. Tried to allocate 400.00 MiB (GPU 0; 12.00 GiB total capacity; 9.80 GiB already allocated; 0 bytes free; 9.92 GiB reserved in total by PyTorch)
# ...

# %%
# !python train.py --img 1280 --batch -1 --epochs 25 --data "E:\IVISION\IVISION detection.v7i.yolov5pytorch\data.yaml" --weights yolov5l6.pt --project "ivision" --name "yolov5l6_1280_very_hard"
# Out:
# github:  YOLOv5 is out of date by 41 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# wandb: Currently logged in as: victor30608 (use `wandb login --relogin` to force relogin)
# train: weights=yolov5l6.pt, cfg=, data=E:\IVISION\IVISION detection.v7i.yolov5pytorch\data.yaml, hyp=data\hyps\hyp.scratch.yaml, epochs=25, batch_size=-1, imgsz=1280, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=ivision, name=yolov5l6_1280_very_hard, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLOv5  v6.0-151-gabbdd48 torch 1.9.0+cu111 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
#
# ...

# %%
# !python train.py --img 1280 --batch -1 --epochs 25 --data "E:\IVISION\IVISION detection.v7i.yolov5pytorch\data.yaml" --weights yolov5l6.pt --project "ivision" --name "yolov5l6_1280_very_hard"

# %%
# !python train.py --img 1280 --batch -1 --epochs 25 --data "E:\IVISION\IVISION detection.v8i.yolov5pytorch\data.yaml" --weights yolov5l6.pt --project "ivision" --name "yolov5l6_1280_last"
# Out:
# github:  YOLOv5 is out of date by 41 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
#
#       Params      GFLOPs  GPU_mem (GB)  forward (ms) backward (ms)                   input                  output
#     76162504       440.7         3.198         70.73         99.94      (1, 3, 1280, 1280)                    list
#     76162504       881.4         5.394         110.3         175.2      (2, 3, 1280, 1280)                    list
#     76162504        1763         9.137         197.4         446.4      (4, 3, 1280, 1280)                    list
# CUDA out of memory. Tried to allocate 26.00 MiB (GPU 0; 12.00 GiB total capacity; 10.11 GiB already allocated; 0 bytes free; 10.29 GiB reserved in total by PyTorch)
# CUDA out of memory. Tried to allocate 400.00 MiB (GPU 0; 12.00 GiB total capacity; 9.80 GiB already allocated; 125.06 MiB free; 9.92 GiB reserved in total by PyTorch)
# module 'signal' has no attribute 'SIGALRM'
# ...

# %% [markdown]
# ## VALIDATE

# %%
object_path = r"E:\IVISION\test_little"
save_path = r"E:\IVISION\test_little\all"
for folder in os.listdir(object_path):
    os.makedirs(save_path, exist_ok=True)
    for file in os.listdir(os.path.join(object_path,folder)):
        copyfile(os.path.join(object_path,folder,file), os.path.join(save_path,folder+"_"+file))

# %%
# !python detect.py --img 1280 --source "E:\IVISION\test\all" --weights " ivision\yolov5l6_1280_last\weights\best.pt" --save-txt --save-conf --name "ivision_nodtp_v4"
# Out:
# detect: weights=[' ivision\\yolov5l6_1280_last\\weights\\best.pt'], source=E:\IVISION\test\all, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=ivision_nodtp_v4, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5  v6.0-151-gabbdd48 torch 1.9.0+cu111 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
#
# Fusing layers...
# Model Summary: 476 layers, 76118664 parameters, 0 gradients, 110.0 GFLOPs
# image 1/1102 E:\IVISION\test\all\16_0.jpg: 768x1280 Done. (0.059s)
# image 2/1102 E:\IVISION\test\all\16_1.jpg: 768x1280 Done. (0.055s)
# image 3/1102 E:\IVISION\test\all\16_10.jpg: 768x1280 Done. (0.055s)
# image 4/1102 E:\IVISION\test\all\16_11.jpg: 768x1280 Done. (0.054s)
# ...

# %%
# !python detect.py --img 1280 --source "E:\IVISION\test_positive" --weights "S:\WORK\yolov5\ivision\yolov5l6_1280_very_hard2\weights\best.pt" --save-txt --save-conf --name "ivision_dtp_v4"
# Out:
# image 996/1102 E:\IVISION\test\all\48_34.jpg: 768x1280 1 special transport, Done. (0.054s)
# image 997/1102 E:\IVISION\test\all\48_35.jpg: 768x1280 1 special transport, Done. (0.053s)
# image 998/1102 E:\IVISION\test\all\48_36.jpg: 768x1280 1 special transport, Done. (0.053s)
# image 999/1102 E:\IVISION\test\all\48_37.jpg: 768x1280 1 special transport, Done. (0.053s)
# image 1000/1102 E:\IVISION\test\all\48_38.jpg: 768x1280 1 special transport, Done. (0.053s)
# image 1001/1102 E:\IVISION\test\all\48_39.jpg: 768x1280 1 special transport, Done. (0.055s)
# image 1002/1102 E:\IVISION\test\all\48_4.jpg: 768x1280 Done. (0.056s)
# image 1003/1102 E:\IVISION\test\all\48_40.jpg: 768x1280 1 special transport, Done. (0.056s)
# image 1004/1102 E:\IVISION\test\all\48_41.jpg: 768x1280 1 special transport, Done. (0.053s)
# image 1005/1102 E:\IVISION\test\all\48_42.jpg: 768x1280 1 special transport, Done. (0.053s)
# ...

# %%
ivison_nodtp = r"S:\WORK\yolov5\runs\detect\ivision_nodtp_v4\labels"
thresh = 0.75
bad = []
for label in os.listdir(ivison_nodtp):
    with open(os.path.join(ivison_nodtp, label),'r') as file:
        lines = file.readlines()
        for line in lines:
            _,x,y,w,h,conf = [float(t) for t in line.split(" ")]
            if(conf>thresh):
                bad.append(label.split(".")[0]+".jpg")
                print(label.split(".")[0]+".jpg", conf)
images_path = r"E:\IVISION\test\all"
save_path = r"E:\IVISION\hard_samples_v3"
for file in bad:
    copyfile(os.path.join(images_path,file),os.path.join(save_path,file))
# Out:
# 17_7.jpg 0.776513
# 17_8.jpg 0.807999
# 19_0.jpg 0.88476
# 19_1.jpg 0.899981
# 34_11.jpg 0.879563
# 34_12.jpg 0.832668
# 34_13.jpg 0.851968
# 34_25.jpg 0.879787
# 34_26.jpg 0.915972
# 34_27.jpg 0.952577
# 34_28.jpg 0.943491
# 34_29.jpg 0.929322
# 34_30.jpg 0.897308
# 34_31.jpg 0.86338
# 34_32.jpg 0.806517
# 34_33.jpg 0.781057
# 35_11.jpg 0.87022
# 35_12.jpg 0.914293
# 35_13.jpg 0.894752
# 35_14.jpg 0.80525
# 35_15.jpg 0.795601
# 35_16.jpg 0.870964
# 35_17.jpg 0.87508
# 35_18.jpg 0.870694
# 35_19.jpg 0.786074
# 3_25.jpg 0.884823
# 3_26.jpg 0.812442
# 3_27.jpg 0.844083
# 3_28.jpg 0.873277
# 3_29.jpg 0.879408
# 3_30.jpg 0.871808
# 3_31.jpg 0.83712
# 48_31.jpg 0.76923
# 48_32.jpg 0.753866
# 48_35.jpg 0.751083

# %%
# !python detect.py --img 1280 --source "E:\IVISION\test\all" --weights "S:\WORK\yolov5\ivision\yolov5l6_12802\weights\best.pt" --save-txt --save-conf --name "ivision_nodtp"
# Out:
# detect: weights=['S:\\WORK\\yolov5\\ivision\\yolov5l6_12802\\weights\\best.pt'], source=E:\IVISION\test\all, imgsz=[1280, 1280], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=ivision_nodtp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5  v6.0-151-gabbdd48 torch 1.9.0+cu111 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
#
# Fusing layers...
# Model Summary: 476 layers, 76118664 parameters, 0 gradients, 110.0 GFLOPs
# image 1/1102 E:\IVISION\test\all\16_0.jpg: 768x1280 Done. (0.057s)
# image 2/1102 E:\IVISION\test\all\16_1.jpg: 768x1280 Done. (0.052s)
# image 3/1102 E:\IVISION\test\all\16_10.jpg: 768x1280 Done. (0.052s)
# image 4/1102 E:\IVISION\test\all\16_11.jpg: 768x1280 Done. (0.052s)
# ...

# %%
ivison_nodtp = r"S:\WORK\yolov5\runs\detect\ivision_nodtp\labels"
thresh = 0.7
bad = []
for label in os.listdir(ivison_nodtp):
    with open(os.path.join(ivison_nodtp, label),'r') as file:
        lines = file.readlines()
        for line in lines:
            _,x,y,w,h,conf = [float(t) for t in line.split(" ")]
            if(conf>0.7):
                bad.append(label.split(".")[0]+".jpg")

# %%
len(bad)
# Out:
# 84

# %% [markdown]
# # CLASSIFICATION

# %%
image2folders(r"E:\IVISION\dtp_images",r"E:\IVISION\classification\1", dtp_time, 8)
# Out:
# 81 115
# 189 201
# 225 227
# 260 267
# 315 319
# 31 76
# 30 60
# 136 150
# 74 105
# 179 185
# 190 200
# 64 110
# 161 180
# 67 95
# 121 155
# 70 125
# 230 240
# 263 274
# 49 87
# 141 145
# 210 215
# 25 84
# 162 195
# 68 87
# 179 220
# 52 86
# 154 164
# 230 254
# 65 120
# 160 170
# 44 90
# 17 42
# 95 129
# 170 184
# 32 62
# 220 225
# 51 70
# 161 180
# 363 370
# 17 80
# 153 200
# 77 110
# 40 70
# 128 131
# 196 199
# 70 100
# 195 207
# 0 10
# 10 20
# 200 215
# 500 520
# 960 1000
# 1110 1130

# %%
object_path = r"E:\IVISION\classification\1"
save_path = r"E:\IVISION\classification\1"
for folder in os.listdir(object_path):
    os.makedirs(save_path, exist_ok=True)
    for file in os.listdir(os.path.join(object_path,folder)):
        copyfile(os.path.join(object_path,folder,file), os.path.join(save_path,folder+"_"+file))

# %%
object_path = r"E:\IVISION\test"
save_path = r"E:\IVISION\classification\0"
for folder in os.listdir(object_path):
    os.makedirs(save_path, exist_ok=True)
    for file in os.listdir(os.path.join(object_path,folder)):
        copyfile(os.path.join(object_path,folder,file), os.path.join(save_path,folder+"_"+file))

# %% [markdown]
# ### hard samples from dtp

# %%
savepath = r"E:\IVISION\classification\0"
path = r"E:\IVISION\dtp_images"
step = 10
for folder in dtp_time:
    start = 0
    end = dtp_time[folder][0]
    if start==end:
        continue
    for filename in range(start,end,step):
        filename = str(filename)
        filename+=".jpg"
        copyfile(os.path.join(path, str(folder), filename), os.path.join(savepath, str(folder)+"_"+filename))

# %% [markdown]
# ### training

# %%
import os
import glob
import random
import cv2
import numpy as np
from shutil import copyfile

# %%
BATCH_SIZE_TRAINING = 16
BATCH_SIZE_VALIDATION = 4
BATCH_SIZE_TESTING = 1
STEPS_PER_EPOCH_TRAINING = 128
NUM_EPOCHS = 10
HEIGHT, WIDTH, CHANNEL = 350, 350, 3
N_CLASSES = 2 
LEARNING_RATE = 1e-4
WARMUP_LEARNING_RATE = 1e-3
WARMUP_EPOCHS = 3

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import pickle
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, AvgPool2D, BatchNormalization, Reshape, Lambda
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Flatten, GlobalAveragePooling2D, Input, GlobalMaxPooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import optimizers
#from tensorflow.keras.applications.resnet import preprocess_input
from tensorflow.keras.applications.efficientnet import EfficientNetB5
#from tensorflow.keras.applications.xception import preprocess_input
from tensorflow.keras.applications import InceptionResNetV2 
from tensorflow.keras.applications.inception_resnet_v2 import preprocess_input
from tensorflow.keras.applications import Xception
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report

# %%
def create_model(input_shape, n_out):
    input_tensor = Input(shape=input_shape)
    base_model = InceptionResNetV2(include_top=False,
                                       input_tensor=input_tensor,weights="imagenet")
    base_model.trainable = False
    x = GlobalAveragePooling2D()(base_model.output)
    x = Dropout(0.5)(x)
    x = Dense(2048, activation='relu')(x)
    x = Dropout(0.6)(x)
    final_output = Dense(n_out, activation='softmax', name='final_output')(x)
    model = Model(input_tensor, final_output)
    
    return model

# %%
data_generator_train = ImageDataGenerator(preprocessing_function=preprocess_input,   rotation_range=30,
#data_generator_train = ImageDataGenerator(rotation_range=30,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range = 0.1, shear_range=0.1,
    horizontal_flip=True, validation_split=0.1)

data_generator_val = ImageDataGenerator(preprocessing_function=preprocess_input,
#data_generator_val = ImageDataGenerator(
    horizontal_flip=True, validation_split=0.1)

# %%
train_generator = data_generator_train.flow_from_directory(
        r'E:\IVISION\classification',
        target_size=(HEIGHT, WIDTH),
        batch_size= BATCH_SIZE_TRAINING,
        class_mode='categorical', shuffle=True, subset = 'training')



valid_generator = data_generator_train.flow_from_directory(
        r'E:\IVISION\classification',
        target_size=(HEIGHT, WIDTH),
        batch_size = BATCH_SIZE_VALIDATION,
        shuffle=True,
        class_mode='categorical', subset = 'validation')
# Out:
# Found 925 images belonging to 2 classes.
# Found 102 images belonging to 2 classes.

# %%
model = create_model(input_shape=(HEIGHT, WIDTH, CHANNEL), n_out=2)

# %%
for layer in model.layers:
    layer.trainable = False

for i in range(-25, 0):
    model.layers[i].trainable = True

metric_list = ["accuracy"]
optimizer = Adam(lr = 0.0001, decay = 1e-6)
model.compile(optimizer=optimizer, loss="binary_crossentropy",  metrics=metric_list)
model.summary()
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_8 (InputLayer)           [(None, 350, 350, 3  0           []
#                                 )]
#
#  conv2d_414 (Conv2D)            (None, 174, 174, 32  864         ['input_8[0][0]']
#                                 )
#
#  batch_normalization_414 (Batch  (None, 174, 174, 32  96         ['conv2d_414[0][0]']
#  Normalization)                 )
#
#  activation_406 (Activation)    (None, 174, 174, 32  0           ['batch_normalization_414[0][0]']
#                                 )
#
#  conv2d_415 (Conv2D)            (None, 172, 172, 32  9216        ['activation_406[0][0]']
#                                 )
#
#  batch_normalization_415 (Batch  (None, 172, 172, 32  96         ['conv2d_415[0][0]']
#  Normalization)                 )
#
# ...

# %%
STEP_SIZE_TRAIN = train_generator.n//train_generator.batch_size
STEP_SIZE_VALID = valid_generator.n//valid_generator.batch_size

history_warmup = model.fit_generator(generator=train_generator,
                                     steps_per_epoch=STEP_SIZE_TRAIN,
                                     validation_data=valid_generator,
                                     validation_steps=STEP_SIZE_VALID,
                                     epochs=3,
                                     verbose=1).history
# Out:
# C:\Users\331A~1\AppData\Local\Temp/ipykernel_17312/3340683787.py:4: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history_warmup = model.fit_generator(generator=train_generator,
# Epoch 1/3
# 57/57 [==============================] - 37s 560ms/step - loss: 0.5307 - accuracy: 0.7580 - val_loss: 0.5370 - val_accuracy: 0.6800
# Epoch 2/3
# 57/57 [==============================] - 29s 514ms/step - loss: 0.3147 - accuracy: 0.8669 - val_loss: 0.7303 - val_accuracy: 0.6200
# Epoch 3/3
# 57/57 [==============================] - 29s 516ms/step - loss: 0.2409 - accuracy: 0.8922 - val_loss: 0.9452 - val_accuracy: 0.6000

# %%
for layer in model.layers:
    layer.trainable = True

# %%
metric_list = ["accuracy"]
optimizer = Adam(lr = 1e-6)
model.compile(optimizer=optimizer, loss="binary_crossentropy",  metrics=metric_list)
model.summary()
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_8 (InputLayer)           [(None, 350, 350, 3  0           []
#                                 )]
#
#  conv2d_414 (Conv2D)            (None, 174, 174, 32  864         ['input_8[0][0]']
#                                 )
#
#  batch_normalization_414 (Batch  (None, 174, 174, 32  96         ['conv2d_414[0][0]']
#  Normalization)                 )
#
#  activation_406 (Activation)    (None, 174, 174, 32  0           ['batch_normalization_414[0][0]']
#                                 )
#
#  conv2d_415 (Conv2D)            (None, 172, 172, 32  9216        ['activation_406[0][0]']
#                                 )
#
#  batch_normalization_415 (Batch  (None, 172, 172, 32  96         ['conv2d_415[0][0]']
#  Normalization)                 )
#
# ...

# %%
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

cb_early_stopper = EarlyStopping(monitor = 'val_accuracy', patience = 4)
lrr = ReduceLROnPlateau(monitor = 'val_accuracy',
                         patience = 2,
                         verbose = 1,
                         factor = 0.75,
                         min_lr = 1e-8)

callback_list = [cb_early_stopper, lrr]

# %%
train_generator.batch_size = 16
STEP_SIZE_TRAIN = train_generator.n//train_generator.batch_size
STEP_SIZE_VALID = valid_generator.n//valid_generator.batch_size

# %%
history_warmup = model.fit_generator(generator=train_generator,
                                     steps_per_epoch=STEP_SIZE_TRAIN,
                                     validation_data=valid_generator,
                                     validation_steps=STEP_SIZE_VALID,
                                     epochs=15, callbacks = callback_list,
                                     verbose=1).history
# Out:
# C:\Users\331A~1\AppData\Local\Temp/ipykernel_17312/1550178643.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history_warmup = model.fit_generator(generator=train_generator,
# Epoch 1/15
# 57/57 [==============================] - 42s 563ms/step - loss: 0.6533 - accuracy: 0.6700 - val_loss: 0.6536 - val_accuracy: 0.6400 - lr: 1.0000e-06
# Epoch 2/15
# 57/57 [==============================] - 30s 528ms/step - loss: 0.5749 - accuracy: 0.6854 - val_loss: 0.6687 - val_accuracy: 0.5900 - lr: 1.0000e-06
# Epoch 3/15
# 57/57 [==============================] - 31s 544ms/step - loss: 0.5436 - accuracy: 0.6854 - val_loss: 0.6381 - val_accuracy: 0.6000 - lr: 1.0000e-06
# Epoch 4/15
# 57/57 [==============================] - 32s 557ms/step - loss: 0.5025 - accuracy: 0.7217 - val_loss: 0.7421 - val_accuracy: 0.6100 - lr: 1.0000e-06
# Epoch 5/15
# ...

# %%
from sklearn.metrics import classification_report

# get the ground truth of your data. 
test_labels=valid_generator.classes 

# predict the probability distribution of the data
predictions=model.predict_generator(valid_generator, steps=28, verbose=1)

# get the class with highest probability for each sample
y_pred = np.argmax(predictions, axis=-1)

# get the classification report
print(classification_report(test_labels, y_pred))
# Out:
# C:\Users\331A~1\AppData\Local\Temp/ipykernel_17312/3815309052.py:7: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   predictions=model.predict_generator(valid_generator, steps=28, verbose=1)
# ...
# 28/28 [==============================] - 8s 169ms/step
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80        68
#            1       0.00      0.00      0.00        34
#
#     accuracy                           0.67       102
#    macro avg       0.33      0.50      0.40       102
# weighted avg       0.44      0.67      0.53       102
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...
